# %%
# %matplotlib widget
import matplotlib.pylab as plt
from tqdm import trange
import numpy as np
from scipy.stats import ttest_ind
from scipy import stats
import time
import random
import os

# Mostrar una traza
def show_trace(trace):
    x = np.linspace(-5, 5, len(trace))  # Crear eje x con 2000 valores de -2 a 2
    plt.figure()
    plt.figure(figsize=(8, 5))
    plt.plot(x, trace, label="Nivel de confianza acumulado")
    plt.xlim(-5, 5)  # Ventana de valores del eje x
    plt.xlabel("Valor t-test")
    plt.ylabel("Nivel de confianza acumulado (CDF)")
    plt.axvline(x=4.5, color='green', linestyle='--', linewidth=1, label="TVLA umbral +t = 4.5")
    plt.axvline(x=-4.5, color='green', linestyle='--', linewidth=1, label="TVLA umbral -t = 4.5")
    plt.axhline(y=0.95, color='red', linestyle='--', linewidth=1, label="95% de confianza")
    plt.axhline(y=1, color='black', linestyle='--', linewidth=1, label="100% de confianza")
    plt.legend(loc="lower right")
    plt.show()

# %%
valores = []
for i in range(1000):
    valores.append((-1000+i)/40)
for i in range(1000):
    valores.append(i/40)
p_lista = []

df = 20

p_valor = 2 * (1 - stats.t.cdf(t, df))

for valor in valores:
    p_lista.append(1 - (2 * (1 - stats.t.cdf(abs(valor), df))))

# %%
show_trace(p_lista)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
show_trace(p_lista)
# Out:
# 2000
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt
import numpy as np

# Crear la lista de valores
valores = []
for i in range(1000):
    valores.append((-1000 + i) / 1000)
for i in range(1000):
    valores.append(i / 1000)

p_lista = []
for valor in valores:
    p_lista.append(1 - (2 * (1 - stats.t.cdf(abs(valor), df))))

# Crear eje x de -2 a 2 con 2000 puntos
x = np.linspace(-2, 2, len(p_lista))

# Graficar
plt.plot(x, p_lista, linewidth=1)
plt.xlim(-2, 2)
plt.xlabel("Eje X (de -2 a 2)")
plt.ylabel("Valores")
plt.title("Gráfico de 2000 valores con eje X de -2 a 2")
plt.grid(True)
plt.show()
print(p_lista)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# [0.6707434228282909, 0.670271095476934, 0.6697982959898636, 0.6693250243235243, 0.668851280435298, 0.668377064283507, 0.6679023758274141, 0.6674272150272247, 0.6669515818440881, 0.666475476240098, 0.6659988981782949, 0.6655218476226668, 0.665044324538151, 0.6645663288906349, 0.6640878606469571, 0.6636089197749104, 0.6631295062432403, 0.662649620021649, 0.6621692610807952, 0.6616884293922962, 0.6612071249287286, 0.6607253476636292, 0.6602430975714983, 0.6597603746277985, 0.6592771788089575, 0.658793510092369, 0.6583093684563939, 0.6578247538803621, 0.657339666344573, 0.656854105830297, 0.6563680723197778, 0.6558815657962316, 0.6553945862438506, 0.6549071336478032, 0.6544192079942346, 0.6539308092702696, 0.6534419374640126, 0.6529525925645494, 0.6524627745619485, 0.6519724834472624, 0.651481719212528, 0.6509904818507697, 0.6504987713559984, 0.6500065877232148, 0.6495139309484088, 0.6490208010285614, 0.6485271979616478, 0.6480331217466353, 0.6475385723834868, 0.6470435498731615, 0.6465480542176161, 0.646052085419806, 0.6455556434836858